# %%
# Mount google drive to import/export files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Install xattr
# !apt-get install -qq xattr
# Out:
# Selecting previously unselected package python3-cffi-backend.
# (Reading database ... 134443 files and directories currently installed.)
# Preparing to unpack .../0-python3-cffi-backend_1.11.5-1_amd64.deb ...
# Unpacking python3-cffi-backend (1.11.5-1) ...
# Selecting previously unselected package python3-ply.
# Preparing to unpack .../1-python3-ply_3.11-1_all.deb ...
# Unpacking python3-ply (3.11-1) ...
# Selecting previously unselected package python3-pycparser.
# Preparing to unpack .../2-python3-pycparser_2.18-2_all.deb ...
# Unpacking python3-pycparser (2.18-2) ...
# Selecting previously unselected package python3-cffi.
# Preparing to unpack .../3-python3-cffi_1.11.5-1_all.deb ...
# Unpacking python3-cffi (1.11.5-1) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../4-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-xattr.
# ...

# %%
# Cd to directory of your file, replace yolo-1c.cfg with your filename
# Make sure file is set to public
# %cd drive/My Drive/fall19_smithsonian_informatics/train
# !xattr -p 'user.drive.id' xml_for_Lepidoptera_train.txt
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/fall19_smithsonian_informatics/train'
# /content/drive/My Drive/fall19_smithsonian_informatics/train
# 1QO0JpTb_1kBHq3HttxefEpJBkXqt1KBE

# %%
# Test download with generated id, replace fileid with output from cell above
# !gdown --id 13mPZ5Ajtnp-tuE75Eov8Q8D5aDQzwtHd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=13mPZ5Ajtnp-tuE75Eov8Q8D5aDQzwtHd
# To: /content/drive/My Drive/fall19_smithsonian_informatics/train/python/generate_tfrecord.py
# 100% 3.48k/3.48k [00:00<00:00, 1.34MB/s]
